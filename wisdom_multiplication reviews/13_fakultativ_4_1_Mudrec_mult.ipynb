# %% [markdown]
# # Внимание! Время работы программы около 120 секунд.
# На моем компьютере
# # Выходной файл: wisdom_mult.png

# %% [markdown]
# Server Information:
#
# Jupyter notebook server: 6.0.3
#
# Python 3.8.3 (default, Jul 2 2020, 17:30:36) [MSC v.1916 64 bit (AMD64)]

# %% [markdown]
# 1. Построить таблицу умножения двузначных чисел (от 10 до 99), без сокращений.
#     рекомендуется заполнять таблицу записями вида NxM, а не результатами
#     (т.е. таблица очень большая и в середине не видно индексов столбцов и строк).
# 2. Визуально отметить те ячейки таблицы, где работает "схема мудреца"
#     (разными цветами те где достаточно схемы без проверки на разделитель 0 внутри и те,
#      где это является необходимым условием верного ответа)
# 3. Добавить комментарии в код (включая функции)
# 4. Сохранить результат в файл (любого типа, но рекомендуется html или png)

# %%
import time
# время работы программы
start_time = time.time()

import matplotlib.pyplot as plt

def wisdom_multiplication(x, y, length_check = True):
    # Вычисление произведения по схеме мудреца
    # length_check=false - не добавлять нули в центр 
    # length_check=true - добавлять нули в центр 
    
    n1=100-x
    n2=100-y
    out1=str(100-n1-n2)
    out2=str(n1*n2)
    if length_check and len(out2)==1:
        out2=("00"+out2)[1:]
    return int(out1+out2)

def wisdom_mult_check(x,y):
    # Проверка схемы мудреца
    # Возвращает 0, если схема мудреца не работает
    # Возвращает 1, если схема мудреца работает при добавлении нулей в центр числа
    # Возвращает 2, если схема мудреца работает
    
    if x*y == wisdom_multiplication(x, y, length_check = False): return 2
    if x*y == wisdom_multiplication(x, y, length_check = True): return 1
    else: return 0
    
# не показвать оси
sides = ('left', 'right', 'top', 'bottom')
nolabels = {s: False for s in sides}
nolabels.update({'label%s' % s: False for s in sides}) 
colors=['white','white','black'] # цвет текста

start=10
end=100
# Заполнение таблицы результатами проверки схемы мудреца
x=[[wisdom_mult_check(i,j) for j in range(start,end)] for i in range(start,end)] 

# визуализация таблицы    
fig, ax = plt.subplots(1, 1, figsize=(50, 50))
fig.suptitle('Таблица умножения по методу мудреца', fontsize=20)
ax.set_title('СИНИЙ - не работает, ЗЕЛЕНЫЙ - работает с добавлением нулей в центр числа, ЖЕЛТЫЙ - работает', \
             fontsize=20)         
ax.tick_params(axis='both', which='both', **nolabels)
 
# Подписи внутри ячеек таблицы
for i in range(end-start):
    for j in range(end-start):
        ax.text(i, j,  str(i+start)+'$\cdot$'+str(j+start), color=colors[x[i][j]], ha='center', va='center')
ax.matshow(x)

fig.savefig('13_wisdom_mult.png')

# время работы программы
print("--- %s seconds ---" % round((time.time() - start_time)))
# Out:
# --- 49 seconds ---
# Error in callback <function flush_figures at 0x0000026518E24EE0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     118         # ignore the tracking, just draw and close all figures
#     119         try:
# --> 120             return show(True)
#     121         except Exception as e:
#     122             # safely show traceback if in IPython, else raise
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      38     try:
#      39         for figure_manager in Gcf.get_all_fig_managers():
# ---> 40             display(
#      41                 figure_manager.canvas.figure,
#      42                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     248
#     249     if 'png' in formats:
# --> 250         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     251     if 'retina' in formats or 'png2x' in formats:
#     252         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     132         FigureCanvasBase(fig)
#     133
# --> 134     fig.canvas.print_figure(bytes_io, **kw)
#     135     data = bytes_io.getvalue()
#     136     if fmt == 'svg':
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2232             if bbox_inches:
#    2233                 if bbox_inches == "tight":
# -> 2234                     bbox_inches = self.figure.get_tightbbox(
#    2235                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2236                     if pad_inches is None:
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    1634
#    1635         for a in artists:
# -> 1636             bbox = a.get_tightbbox(renderer)
#    1637             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    1638                 bb.append(bbox)
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4482                     # this artist
#    4483                     continue
# -> 4484             bbox = a.get_tightbbox(renderer)
#    4485             if (bbox is not None
#    4486                     and 0 < bbox.width < np.inf
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\artist.py in get_tightbbox(self, renderer)
#     304             The enclosing bounding box (in figure pixel coordinates).
#     305         """
# --> 306         bbox = self.get_window_extent(renderer)
#     307         if self.get_clip_on():
#     308             clip_box = self.get_clip_box()
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     901
#     902         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 903             bbox, info, descent = self._get_layout(self._renderer)
#     904             x, y = self.get_unitless_position()
#     905             x, y = self.get_transform().transform((x, y))
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     312             clean_line, ismath = self._preprocess_math(line)
#     313             if clean_line:
# --> 314                 w, h, d = renderer.get_text_width_height_descent(
#     315                     clean_line, self._fontproperties, ismath=ismath)
#     316             else:
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     233         if ismath:
#     234             ox, oy, width, height, descent, fonts, used_characters = \
# --> 235                 self.mathtext_parser.parse(s, self.dpi, prop)
#     236             return width, height, descent
#     237
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\mathtext.py in parse(self, s, dpi, prop, _force_standard_ps_fonts)
#     450         # mathtext.fontset rcParams also affect the parse (e.g. by affecting
#     451         # the glyph metrics).
# --> 452         return self._parse_cached(s, dpi, prop, _force_standard_ps_fonts)
#     453
#     454     @functools.lru_cache(50)
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\mathtext.py in _parse_cached(self, s, dpi, prop, force_standard_ps_fonts)
#     471             self.__class__._parser = _mathtext.Parser()
#     472
# --> 473         box = self._parser.parse(s, font_output, fontsize, dpi)
#     474         font_output.set_canvas_size(box.width, box.height, box.depth)
#     475         return font_output.get_results(box)
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\_mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2275         self._em_width_cache = {}
#    2276         try:
# -> 2277             result = self._expression.parseString(s)
#    2278         except ParseBaseException as err:
#    2279             raise ValueError("\n".join(["",
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1941             instring = instring.expandtabs()
#    1942         try:
# -> 1943             loc, tokens = self._parse(instring, 0)
#    1944             if parseAll:
#    1945                 loc = self.preParse(instring, loc)
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1842                 ParserElement.packrat_cache_stats[MISS] += 1
#    1843                 try:
# -> 1844                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1845                 except ParseBaseException as pe:
#    1846                     # cache a copy of the exception, without the traceback
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4460     def parseImpl(self, instring, loc, doActions=True):
#    4461         if self.expr is not None:
# -> 4462             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4463         else:
#    4464             raise ParseException("", loc, self.errmsg, self)
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1842                 ParserElement.packrat_cache_stats[MISS] += 1
#    1843                 try:
# -> 1844                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1845                 except ParseBaseException as pe:
#    1846                     # cache a copy of the exception, without the traceback
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4050         # pass False as last arg to _parse for first element, since we already
#    4051         # pre-parsed the string as part of our And pre-parsing
# -> 4052         loc, resultlist = self.exprs[0]._parse(instring, loc, doActions, callPreParse=False)
#    4053         errorStop = False
#    4054         for e in self.exprs[1:]:
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1842                 ParserElement.packrat_cache_stats[MISS] += 1
#    1843                 try:
# -> 1844                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1845                 except ParseBaseException as pe:
#    1846                     # cache a copy of the exception, without the traceback
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1714                 for fn in self.parseAction:
#    1715                     try:
# -> 1716                         tokens = fn(instring, tokensStart, retTokens)
#    1717                     except IndexError as parse_action_exc:
#    1718                         exc = ParseException("exception raised in parse action")
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\pyparsing.py in wrapper(*args)
#    1314         while 1:
#    1315             try:
# -> 1316                 ret = func(*args[limit[0]:])
#    1317                 foundArity[0] = True
#    1318                 return ret
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\_mathtext.py in non_math(self, s, loc, toks)
#    2347     def non_math(self, s, loc, toks):
#    2348         s = toks[0].replace(r'\$', '$')
# -> 2349         symbols = [Char(c, self.get_state(), math=False) for c in s]
#    2350         hlist = Hlist(symbols)
#    2351         # We're going into math now, so set font to 'it'
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\_mathtext.py in <listcomp>(.0)
#    2347     def non_math(self, s, loc, toks):
#    2348         s = toks[0].replace(r'\$', '$')
# -> 2349         symbols = [Char(c, self.get_state(), math=False) for c in s]
#    2350         hlist = Hlist(symbols)
#    2351         # We're going into math now, so set font to 'it'
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\_mathtext.py in __init__(self, c, state, math)
#    1147         # The real width, height and depth will be set during the
#    1148         # pack phase, after we know the real fontsize
# -> 1149         self._update_metrics()
#    1150
#    1151     def __repr__(self):
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\_mathtext.py in _update_metrics(self)
#    1153
#    1154     def _update_metrics(self):
# -> 1155         metrics = self._metrics = self.font_output.get_metrics(
#    1156             self.font, self.font_class, self.c, self.fontsize, self.dpi,
#    1157             self.math)
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\_mathtext.py in get_metrics(self, font, font_class, sym, fontsize, dpi, math)
#     147               (currently used for kerning sub/superscripts).
#     148         """
# --> 149         info = self._get_info(font, font_class, sym, fontsize, dpi, math)
#     150         return info.metrics
#     151
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\_mathtext.py in _get_info(self, fontname, font_class, sym, fontsize, dpi, math)
#     265
#     266         font, num, symbol_name, fontsize, slanted = \
# --> 267             self._get_glyph(fontname, font_class, sym, fontsize, math)
#     268
#     269         font.set_size(fontsize, dpi)
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\_mathtext.py in _get_glyph(self, fontname, font_class, sym, fontsize, math)
#     597             # check whether the glyph is available in the display font
#     598             uniindex = get_unicode_index(sym)
# --> 599             font = self._get_font('ex')
#     600             if font is not None:
#     601                 glyphindex = font.get_char_index(uniindex)
#
# c:\users\mps10722\documents\python\learning\практикум по математике и python\venv\lib\site-packages\matplotlib\_mathtext.py in _get_font(self, font)
#     246             basename = font
#     247         cached_font = self._fonts.get(basename)
# --> 248         if cached_font is None and os.path.exists(basename):
#     249             cached_font = get_font(basename)
#     250             self._fonts[basename] = cached_font
#
# ~\AppData\Local\Programs\Python\Python39\lib\genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except (OSError, ValueError):
#      21         return False
#
# KeyboardInterrupt:
