# %%
import pandas as pd
from collections import defaultdict


def wisdom_multiplication(x, y, length_check=True):
    # Функция реализующую умножение по схеме "мудреца" с конкатенацией.
    # Взята из задания https://stepik.org/lesson/240851/step/7?unit=213481
    firstpair = str(100 - ((100 - x) + (100 - y)))
    secondpair = str((100 - x) * (100 - y))
    if length_check and len(secondpair) == 1: secondpair = '0' + secondpair
    return int(firstpair + secondpair)


def color_cell(val):
    # Функция возвращает цвет фона ячейки провверяемого произведения, вызывается из стайлера
    xy = int(val.split('=')[1])                     # выделение произведения числе
    x, y = map(int, val.split('=')[0].split('x'))   # выделение множителей
    background_color = ''                           # фон по умолчанию
    if wisdom_multiplication(x, y) == xy:           # проверка произведения по схеме "мудреца"
        if wisdom_multiplication(x, y, length_check=False) == xy:   # схема от "Мудреца" работает
            background_color = 'background-color: #00FF00'          # Фон ячеек: Зеленый
        else:                                                       # Необходима проверка на "0" между парами чисел
            background_color = 'background-color: #FFFF00'          # Фон ячеек: Зеленый
    return background_color

# создание словаря-массива с таблицей умножения двухзначных чисел
y,dy = 10, 90
x,dx = 10, 90
dct = defaultdict(list)
for i in range(x, x+dx):
    for j in range(y, y+dy):
        dct[str(i)].append(f'{j}x{i}={j*i}')
        
# создание датафрейма из словаря с индексами строк
df = pd.DataFrame(dct, index=[str(c) for c in range(y, y+dy)])

head_txt = ['Таблица умножения двузначных чисел.',
            'Фон ячеек: Зеленый - схема от "Мудреца" работает, Желтый - необходима проверка на "0" между парами чисел.']
print(*head_txt,sep='\n')                   # печать заголовка

pd.set_option('display.max_rows', 99)       # увеличения лимита отображаемых строк
pd.set_option('display.max_columns', 99)    # увеличения лимита отображаемых столбцов
df.style                                    # применерие к датафрейму стиля по умолчанию
dfs = df.style.applymap(color_cell)         # раскраска таблицы с помощью стайлера - передается имя функции
dfs                                         # отображение таблицы в Jupyter Notebook

# выгрузка в html (для выгрузки раскомментарить эту секцию, для отображения в в Jupyter Notebook - закомментарить)
# формирование текста с html из датафрейма с применением стайлера
html = (
        df.style
        .applymap(color_cell)
        .render()
        )
# запись в файл заголовка таблицы и данных из датафрейма
# файл создается в каталоге со скриптами по умолчанию
with open("wisdom.html", "w") as ouf:
    # запись в файл заголовка
    ouf.write("<html><body lang=RU style='tab-interval:30pt'>")
    ouf.write(f"<p class=MsoNormal><span style='font-size:18.0pt'>{head_txt[0]}</span></p>")
    ouf.write(f"<p class=MsoNormal><span style='font-size:14.0pt'>{head_txt[1]}</span></p>")
    ouf.write("</body>")
    ouf.write(html)         # запись в файл текста из датафрейма
    ouf.write('</html>')
# Out:
# Таблица умножения двузначных чисел.
# Фон ячеек: Зеленый - схема от "Мудреца" работает, Желтый - необходима проверка на "0" между парами чисел.
# <style  type="text/css" >
#     #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow0_col80 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow0_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow1_col79 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow1_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow2_col78 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow2_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow3_col77 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow3_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow4_col76 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow4_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow5_col75 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow5_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow6_col74 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow6_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow7_col73 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow7_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow8_col72 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow8_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow9_col71 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow9_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow10_col70 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow10_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow11_col69 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow11_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow12_col68 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow12_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow13_col67 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow13_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow14_col66 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow14_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow15_col65 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow15_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow16_col64 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow16_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow17_col63 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow17_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow18_col62 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow18_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow19_col61 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow19_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow20_col60 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow20_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow21_col59 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow21_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow22_col58 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow22_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow23_col57 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow23_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow24_col56 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow24_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow25_col55 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow25_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow26_col54 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow26_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow27_col53 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow27_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow28_col52 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow28_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow29_col51 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow29_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow30_col50 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow30_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow31_col49 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow31_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow32_col48 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow32_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow33_col47 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow33_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow34_col46 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow34_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow35_col45 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow35_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow36_col44 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow36_col89 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93brow37_col43 {
#             background-color:  #00FF00;
#         }    #T_c8383ac2_28a0_11ea_96ad_98eecb23e93br
